# %%
import pandas as pd
import numpy as np
import re

# %%
 data = pd.read_excel(r'./1 E.1 分部分项工程量清单计价表.xls')

# %%
data.columns = data.iloc[1]

# %%
df = pd.DataFrame(columns=data.columns)

# %%
data
# Out:
# 1                 序号          项目编码    项目名称  \
# 0     工程名称：淮河路-土石方工程           NaN     NaN
# 1                 序号          项目编码    项目名称
# 2                NaN           NaN     NaN
# 3                NaN           NaN     NaN
# 4                  1  040101001001   挖一般土方
# 5                  2  040101001002   挖一般土方
# 6                NaN           NaN     NaN
# 7                  3  040101005001  挖淤泥、流砂
# 8                  4  040101002001   挖沟槽土方
# 9                NaN           NaN     NaN
# 10               NaN           NaN     NaN
# 11                 5  040103001001     回填方
# 12               NaN           NaN     NaN
# 13                 6  040103001002     回填方
# 14               NaN           NaN     NaN
# 15               NaN           NaN     NaN
# 16               NaN           NaN     NaN
# 17               NaN           NaN     NaN
# 18               NaN           NaN     NaN
# 19  E.1 分部分项工程量清单计价表           NaN     NaN
# 20    工程名称：淮河路-土石方工程           NaN     NaN
# ...

# %%
for index,row in data.iterrows():
    if re.match('\d+',str(row['项目编码'])):
        df = df.append(row)

# %%
df
# Out:
# 1   序号          项目编码    项目名称  \
# 4    1  040101001001   挖一般土方
# 5    2  040101001002   挖一般土方
# 7    3  040101005001  挖淤泥、流砂
# 8    4  040101002001   挖沟槽土方
# 11   5  040103001001     回填方
# 13   6  040103001002     回填方
# 24   7  040103001003     回填方
# 26   8  040103001004     回填方
# 28   9  040103001005     回填方
# 30  10  040103001006     回填方
# 32  11  040101003001   挖基坑土方
# 44  12  040103001007     回填方
# 46  13  040103001008     回填方
# 48  14  040103001009     回填方
# 50  15  040103001010     回填方
# 68  16  040103002001    余方弃置
# 73  17  040103002002      缺方
#
# 1                                              项目特征描述  NaN 计量\n单位       工程量  \
# 4            1、部位：清表土方\n2、土壤类别：参见地勘报告及自行现场勘察\n3、含场内倒运  NaN     m3  35094.20
# 5   1、部位：路基挖方含反挖\n2、土壤类别：参见地勘报告及自行现场勘察\n3、挖土深度：详见道...  NaN     m3  25186.54
# 7               1、部位：沟塘清淤\n2、挖掘深度：详见设计图纸\n3、其他：详见设计图纸  NaN     m3   2628.80
# 8   1、部位：雨污水管网沟槽\n2、土壤类别：自行勘察现场考虑\n3、挖土深度：详见排水纵断面图...  NaN     m3  50330.82
# ...
